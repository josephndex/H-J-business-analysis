# %%
import pandas as pd
import numpy as np

# %%
# Read the Excel file, skipping the first row and making the second row the header 
df = pd.read_excel("hj actuall.xlsx", header=None, skiprows=2) 
# Set the first row as the header 
df.columns = df.iloc[0] 
# Drop the first row from the DataFrame 
df = df[1:]
#  # Display the DataFrame 
hj=df.copy()

# %%
# CREATE A profit per product collumn
hj["Profit per product"]=hj["Final Market Selling Price"] - hj["Original Price per Product in Kenyan Shillings"]
hj
# Out:
# 0                      BATH AND BODY WORKS PRODUCTS Number of products  \
# 1                        Champagne Toast Body Cream                  3
# 2                       Champagne Toast body splash                  1
# 3                      A thousand Wishes Body Cream                  2
# 4                     A thousand Wishes Body Splash                  1
# 5                     A thousand Wishes Body lotion                  1
# 6                   A thousand Wishes, Diamond Mist                  2
# 7                           Canyon Body Cream (men)                  2
# 8                          Bourbon Body Cream (Men)                  3
# 9                  Bourbon Face and body wash (Men)                  1
# 10                         Bourbon Body Spray (Men)                  1
# 11                          Bourbon Deodorant (Men)                  2
# 12                      After Dark Body Cream (Men)                  2
# ...

# %%
# separate all the products according to the cattegory
hjcream=hj[hj["BATH AND BODY WORKS PRODUCTS"].str.contains("Cream",case=False,na=False)].reset_index(drop=True)
hjsplash=hj[hj["BATH AND BODY WORKS PRODUCTS"].str.contains("Splash",case=False,na=False)].reset_index(drop=True)
hjlotion=hj[hj["BATH AND BODY WORKS PRODUCTS"].str.contains("Lotion",case=False,na=False)].reset_index(drop=True)
hjwash=hj[hj["BATH AND BODY WORKS PRODUCTS"].str.contains("Wash",case=False,na=False)].reset_index(drop=True)
hjmist=hj[hj["BATH AND BODY WORKS PRODUCTS"].str.contains("Mist",case=False,na=False)].reset_index(drop=True)
hjsoap=hj[hj["BATH AND BODY WORKS PRODUCTS"].str.contains("Soap",case=False,na=False)].reset_index(drop=True)
hjspray=hj[hj["BATH AND BODY WORKS PRODUCTS"].str.contains("Spray",case=False,na=False)].reset_index(drop=True)
hjdeodorant=hj[hj["BATH AND BODY WORKS PRODUCTS"].str.contains("Deodorant",case=False,na=False)].reset_index(drop=True)
hjbutter=hj[hj["BATH AND BODY WORKS PRODUCTS"].str.contains("Butter",case=False,na=False)].reset_index(drop=True)

# %% [markdown]
# #### cream

# %%
# first we are going to plot a combined line graph of org price and selling
import pandas as pd 
import matplotlib.pyplot as plt
#Plotting the combined line graph 
plt.figure(figsize=(10, 6)) 
plt.plot(hjcream["BATH AND BODY WORKS PRODUCTS"], hjcream["Original Price per Product in Kenyan Shillings"], marker='o', label='Original Price') 
plt.plot(hjcream["BATH AND BODY WORKS PRODUCTS"], hjcream["Final Market Selling Price"], marker='o', label='Final Market Selling Price') 
# Adding title and labels 
plt.title("Comparison Between the Original and Selling Price in Body Cream Products") 
plt.xlabel("BATH AND BODY WORKS PRODUCTS") 
plt.ylabel("Price in Kenyan Shillings (UDS / 127)") 
plt.legend() 
# Set the Y-axis limits 
plt.ylim(600, 1800) 
# Display the graph 
plt.xticks(rotation=45) 
plt.tight_layout()
plt.grid() 
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Assuming hjcream is your DataFrame

# Set the X-axis range
x = np.arange(len(hjcream["BATH AND BODY WORKS PRODUCTS"]))

# Bar width
width = 0.35

# Plotting the grouped bar graph
fig, ax = plt.subplots(figsize=(14, 8))
bar1 = ax.bar(x - width/2, hjcream["Number of products"], width, label='Number of Products', color='skyblue')
bar2 = ax.bar(x + width/2, hjcream["Products Sold"], width, label='Products Sold', color='orange')

# Adding title and labels
ax.set_title("Number of Cream Products Against the Products Sold")
ax.set_xlabel("BATH AND BODY WORKS PRODUCTS")
ax.set_ylabel("Quantity")
ax.set_xticks(x)
ax.set_xticklabels(hjcream["BATH AND BODY WORKS PRODUCTS"], rotation=45, ha='right')
ax.legend()

# Adjust layout to fit all elements
plt.tight_layout()
plt.grid(axis='y')

# Display the graph
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming hjcream is your DataFrame and it already has the 'Profit per product' column

# Plotting the bar graph
plt.figure(figsize=(14, 8))
plt.bar(hjcream["BATH AND BODY WORKS PRODUCTS"], hjcream["Profit per product"], color='green')

# Adding title and labels
plt.title("Profit per cream Product")
plt.xlabel("BATH AND BODY WORKS PRODUCTS")
plt.ylabel("Profit per Product in Kenyan Shillings")

# Adjust layout to fit all elements
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Display the graph
plt.grid(axis='y')
plt.show()

# %%
# first we are going to plot a combined line graph of org price and selling
import pandas as pd 
import matplotlib.pyplot as plt
#Plotting the combined line graph 
plt.figure(figsize=(10, 6)) 
plt.plot(hjsplash["BATH AND BODY WORKS PRODUCTS"], hjsplash["Original Price per Product in Kenyan Shillings"], marker='o', label='Original Price') 
plt.plot(hjsplash["BATH AND BODY WORKS PRODUCTS"], hjsplash["Final Market Selling Price"], marker='o', label='Final Market Selling Price') 
# Adding title and labels 
plt.title("Comparison Between the Original and Selling Price in Body splash Products") 
plt.xlabel("BATH AND BODY WORKS PRODUCTS") 
plt.ylabel("Price in Kenyan Shillings (UDS / 127)") 
plt.legend() 
# Set the Y-axis limits 
plt.ylim(500, 1800) 
# Display the graph 
plt.xticks(rotation=45) 
plt.tight_layout()
plt.grid() 
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Assuming hjcream is your DataFrame

# Set the X-axis range
x = np.arange(len(hjsplash["BATH AND BODY WORKS PRODUCTS"]))

# Bar width
width = 0.35

# Plotting the grouped bar graph
fig, ax = plt.subplots(figsize=(14, 8))
bar1 = ax.bar(x - width/2, hjsplash["Number of products"], width, label='Number of Products', color='skyblue')
bar2 = ax.bar(x + width/2, hjsplash["Products Sold"], width, label='Products Sold', color='orange')

# Adding title and labels
ax.set_title("Number of splash Products bought Against the Products Sold")
ax.set_xlabel("BATH AND BODY WORKS PRODUCTS")
ax.set_ylabel("Quantity")
ax.set_xticks(x)
ax.set_xticklabels(hjsplash["BATH AND BODY WORKS PRODUCTS"], rotation=45, ha='right')
ax.legend()

# Adjust layout to fit all elements
plt.tight_layout()
plt.grid(axis='y')

# Display the graph
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming hjcream is your DataFrame and it already has the 'Profit per product' column

# Plotting the bar graph
plt.figure(figsize=(14, 8))
plt.bar(hjsplash["BATH AND BODY WORKS PRODUCTS"], hjsplash["Profit per product"], color='green')

# Adding title and labels
plt.title("Profit per splash Product")
plt.xlabel("BATH AND BODY WORKS PRODUCTS")
plt.ylabel("Profit per Product in Kenyan Shillings")

# Adjust layout to fit all elements
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Display the graph
plt.grid(axis='y')
plt.show()

# %%
# first we are going to plot a combined line graph of org price and selling
import pandas as pd 
import matplotlib.pyplot as plt
#Plotting the combined line graph 
plt.figure(figsize=(10, 6)) 
plt.plot(hjlotion["BATH AND BODY WORKS PRODUCTS"], hjlotion["Original Price per Product in Kenyan Shillings"], marker='o', label='Original Price') 
plt.plot(hjlotion["BATH AND BODY WORKS PRODUCTS"], hjlotion["Final Market Selling Price"], marker='o', label='Final Market Selling Price') 
# Adding title and labels 
plt.title("Comparison Between the Original and Selling Price in Body lotion Products") 
plt.xlabel("BATH AND BODY WORKS PRODUCTS") 
plt.ylabel("Price in Kenyan Shillings (UDS / 127)") 
plt.legend() 
# Set the Y-axis limits 
plt.ylim(500, 1500) 
# Display the graph 
plt.xticks(rotation=45) 
plt.tight_layout()
plt.grid() 
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Assuming hjcream is your DataFrame

# Set the X-axis range
x = np.arange(len(hjlotion["BATH AND BODY WORKS PRODUCTS"]))

# Bar width
width = 0.35

# Plotting the grouped bar graph
fig, ax = plt.subplots(figsize=(14, 8))
bar1 = ax.bar(x - width/2, hjlotion["Number of products"], width, label='Number of Products', color='skyblue')
bar2 = ax.bar(x + width/2, hjlotion["Products Sold"], width, label='Products Sold', color='orange')

# Adding title and labels
ax.set_title("Number of lotion Products bought Against the Products Sold")
ax.set_xlabel("BATH AND BODY WORKS PRODUCTS")
ax.set_ylabel("Quantity")
ax.set_xticks(x)
ax.set_xticklabels(hjlotion["BATH AND BODY WORKS PRODUCTS"], rotation=45, ha='right')
ax.legend()

# Adjust layout to fit all elements
plt.tight_layout()
plt.grid(axis='y')

# Display the graph
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming hjcream is your DataFrame and it already has the 'Profit per product' column

# Plotting the bar graph
plt.figure(figsize=(14, 8))
plt.bar(hjlotion["BATH AND BODY WORKS PRODUCTS"], hjlotion["Profit per product"], color='green')

# Adding title and labels
plt.title("Profit per lotion Product")
plt.xlabel("BATH AND BODY WORKS PRODUCTS")
plt.ylabel("Profit per Product in Kenyan Shillings")

# Adjust layout to fit all elements
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Display the graph
plt.grid(axis='y')
plt.show()

# %%
# first we are going to plot a combined line graph of org price and selling
import pandas as pd 
import matplotlib.pyplot as plt
#Plotting the combined line graph 
plt.figure(figsize=(10, 6)) 
plt.plot(hjwash["BATH AND BODY WORKS PRODUCTS"], hjwash["Original Price per Product in Kenyan Shillings"], marker='o', label='Original Price') 
plt.plot(hjwash["BATH AND BODY WORKS PRODUCTS"], hjwash["Final Market Selling Price"], marker='o', label='Final Market Selling Price') 
# Adding title and labels 
plt.title("Comparison Between the Original and Selling Price in Body wash Products") 
plt.xlabel("BATH AND BODY WORKS PRODUCTS") 
plt.ylabel("Price in Kenyan Shillings (UDS / 127)") 
plt.legend() 
# Set the Y-axis limits 
plt.ylim(1000, 1700) 
# Display the graph 
plt.xticks(rotation=45) 
plt.tight_layout()
plt.grid() 
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Assuming hjcream is your DataFrame

# Set the X-axis range
x = np.arange(len(hjwash["BATH AND BODY WORKS PRODUCTS"]))

# Bar width
width = 0.35

# Plotting the grouped bar graph
fig, ax = plt.subplots(figsize=(14, 8))
bar1 = ax.bar(x - width/2, hjwash["Number of products"], width, label='Number of Products', color='skyblue')
bar2 = ax.bar(x + width/2, hjwash["Products Sold"], width, label='Products Sold', color='orange')

# Adding title and labels
ax.set_title("Number of wash Products bough Against the Products Sold")
ax.set_xlabel("BATH AND BODY WORKS PRODUCTS")
ax.set_ylabel("Quantity")
ax.set_xticks(x)
ax.set_xticklabels(hjwash["BATH AND BODY WORKS PRODUCTS"], rotation=45, ha='right')
ax.legend()

# Adjust layout to fit all elements
plt.tight_layout()
plt.grid(axis='y')

# Display the graph
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming hjcream is your DataFrame and it already has the 'Profit per product' column

# Plotting the bar graph
plt.figure(figsize=(14, 8))
plt.bar(hjwash["BATH AND BODY WORKS PRODUCTS"], hjwash["Profit per product"], color='green')

# Adding title and labels
plt.title("Profit per wash Product")
plt.xlabel("BATH AND BODY WORKS PRODUCTS")
plt.ylabel("Profit per Product in Kenyan Shillings")

# Adjust layout to fit all elements
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Display the graph
plt.grid(axis='y')
plt.show()

# %%
# first we are going to plot a combined line graph of org price and selling
import pandas as pd 
import matplotlib.pyplot as plt
#Plotting the combined line graph 
plt.figure(figsize=(10, 6)) 
plt.plot(hjmist["BATH AND BODY WORKS PRODUCTS"], hjmist["Original Price per Product in Kenyan Shillings"], marker='o', label='Original Price') 
plt.plot(hjmist["BATH AND BODY WORKS PRODUCTS"], hjmist["Final Market Selling Price"], marker='o', label='Final Market Selling Price') 
# Adding title and labels 
plt.title("Comparison Between the Original and Selling Price in Body mist Products") 
plt.xlabel("BATH AND BODY WORKS PRODUCTS") 
plt.ylabel("Price in Kenyan Shillings (UDS / 127)") 
plt.legend() 
# Set the Y-axis limits 
plt.ylim(1000, 1500) 
# Display the graph 
plt.xticks(rotation=45) 
plt.tight_layout()
plt.grid() 
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Assuming hjcream is your DataFrame

# Set the X-axis range
x = np.arange(len(hjmist["BATH AND BODY WORKS PRODUCTS"]))

# Bar width
width = 0.35

# Plotting the grouped bar graph
fig, ax = plt.subplots(figsize=(14, 8))
bar1 = ax.bar(x - width/2, hjmist["Number of products"], width, label='Number of Products', color='skyblue')
bar2 = ax.bar(x + width/2, hjmist["Products Sold"], width, label='Products Sold', color='orange')

# Adding title and labels
ax.set_title("Number of mist Products bought Against the Products Sold")
ax.set_xlabel("BATH AND BODY WORKS PRODUCTS")
ax.set_ylabel("Quantity")
ax.set_xticks(x)
ax.set_xticklabels(hjmist["BATH AND BODY WORKS PRODUCTS"], rotation=45, ha='right')
ax.legend()

# Adjust layout to fit all elements
plt.tight_layout()
plt.grid(axis='y')

# Display the graph
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming hjcream is your DataFrame and it already has the 'Profit per product' column

# Plotting the bar graph
plt.figure(figsize=(14, 8))
plt.bar(hjmist["BATH AND BODY WORKS PRODUCTS"], hjmist["Profit per product"], color='green')

# Adding title and labels
plt.title("Profit per mist Product")
plt.xlabel("BATH AND BODY WORKS PRODUCTS")
plt.ylabel("Profit per Product in Kenyan Shillings")

# Adjust layout to fit all elements
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Display the graph
plt.grid(axis='y')
plt.show()

# %%
# first we are going to plot a combined line graph of org price and selling
import pandas as pd 
import matplotlib.pyplot as plt
#Plotting the combined line graph 
plt.figure(figsize=(10, 6)) 
plt.plot(hjspray["BATH AND BODY WORKS PRODUCTS"], hjspray["Original Price per Product in Kenyan Shillings"], marker='o', label='Original Price') 
plt.plot(hjspray["BATH AND BODY WORKS PRODUCTS"], hjspray["Final Market Selling Price"], marker='o', label='Final Market Selling Price') 
# Adding title and labels 
plt.title("Comparison Between the Original and Selling Price in Body spray Products") 
plt.xlabel("BATH AND BODY WORKS PRODUCTS") 
plt.ylabel("Price in Kenyan Shillings (UDS / 127)") 
plt.legend() 
# Set the Y-axis limits 
plt.ylim(1590, 1620) 
# Display the graph 
plt.xticks(rotation=45) 
plt.tight_layout()
plt.grid() 
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Assuming hjcream is your DataFrame

# Set the X-axis range
x = np.arange(len(hjspray["BATH AND BODY WORKS PRODUCTS"]))

# Bar width
width = 0.35

# Plotting the grouped bar graph
fig, ax = plt.subplots(figsize=(14, 8))
bar1 = ax.bar(x - width/2, hjspray["Number of products"], width, label='Number of Products', color='skyblue')
bar2 = ax.bar(x + width/2, hjspray["Products Sold"], width, label='Products Sold', color='orange')

# Adding title and labels
ax.set_title("Number of spray Products bought Against the Products Sold")
ax.set_xlabel("BATH AND BODY WORKS PRODUCTS")
ax.set_ylabel("Quantity")
ax.set_xticks(x)
ax.set_xticklabels(hjspray["BATH AND BODY WORKS PRODUCTS"], rotation=45, ha='right')
ax.legend()

# Adjust layout to fit all elements
plt.tight_layout()
plt.grid(axis='y')

# Display the graph
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming hjcream is your DataFrame and it already has the 'Profit per product' column

# Plotting the bar graph
plt.figure(figsize=(14, 8))
plt.bar(hjspray["BATH AND BODY WORKS PRODUCTS"], hjspray["Profit per product"], color='green')

# Adding title and labels
plt.title("Profit per spray Product")
plt.xlabel("BATH AND BODY WORKS PRODUCTS")
plt.ylabel("Profit per Product in Kenyan Shillings")

# Adjust layout to fit all elements
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Display the graph
plt.grid(axis='y')
plt.show()

# %%
# first we are going to plot a combined line graph of org price and selling
import pandas as pd 
import matplotlib.pyplot as plt
#Plotting the combined line graph 
plt.figure(figsize=(10, 6)) 
plt.plot(hjdeodorant["BATH AND BODY WORKS PRODUCTS"], hjdeodorant["Original Price per Product in Kenyan Shillings"], marker='o', label='Original Price') 
plt.plot(hjdeodorant["BATH AND BODY WORKS PRODUCTS"], hjdeodorant["Final Market Selling Price"], marker='o', label='Final Market Selling Price') 
# Adding title and labels 
plt.title("Comparison Between the Original and Selling Price in Body deodorant Products") 
plt.xlabel("BATH AND BODY WORKS PRODUCTS") 
plt.ylabel("Price in Kenyan Shillings (UDS / 127)") 
plt.legend() 
# Set the Y-axis limits 
plt.ylim(900, 1670) 
# Display the graph 
plt.xticks(rotation=45) 
plt.tight_layout()
plt.grid() 
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Assuming hjcream is your DataFrame

# Set the X-axis range
x = np.arange(len(hjdeodorant["BATH AND BODY WORKS PRODUCTS"]))

# Bar width
width = 0.35

# Plotting the grouped bar graph
fig, ax = plt.subplots(figsize=(14, 8))
bar1 = ax.bar(x - width/2, hjdeodorant["Number of products"], width, label='Number of Products', color='skyblue')
bar2 = ax.bar(x + width/2, hjdeodorant["Products Sold"], width, label='Products Sold', color='orange')

# Adding title and labels
ax.set_title("Number of deodarant Products bought Against the Products Sold")
ax.set_xlabel("BATH AND BODY WORKS PRODUCTS")
ax.set_ylabel("Quantity")
ax.set_xticks(x)
ax.set_xticklabels(hjdeodorant["BATH AND BODY WORKS PRODUCTS"], rotation=45, ha='right')
ax.legend()

# Adjust layout to fit all elements
plt.tight_layout()
plt.grid(axis='y')

# Display the graph
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming hjcream is your DataFrame and it already has the 'Profit per product' column

# Plotting the bar graph
plt.figure(figsize=(14, 8))
plt.bar(hjdeodorant["BATH AND BODY WORKS PRODUCTS"], hjdeodorant["Profit per product"], color='green')

# Adding title and labels
plt.title("Profit per deodorant Product")
plt.xlabel("BATH AND BODY WORKS PRODUCTS")
plt.ylabel("Profit per Product in Kenyan Shillings")

# Adjust layout to fit all elements
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Display the graph
plt.grid(axis='y')
plt.show()

# %%
# first we are going to plot a combined line graph of org price and selling
import pandas as pd 
import matplotlib.pyplot as plt
#Plotting the combined line graph 
plt.figure(figsize=(10, 6)) 
plt.plot(hjbutter["BATH AND BODY WORKS PRODUCTS"], hjbutter["Original Price per Product in Kenyan Shillings"], marker='o', label='Original Price') 
plt.plot(hjbutter["BATH AND BODY WORKS PRODUCTS"], hjbutter["Final Market Selling Price"], marker='o', label='Final Market Selling Price') 
# Adding title and labels 
plt.title("Comparison Between the Original and Selling Price in Body butter Products") 
plt.xlabel("BATH AND BODY WORKS PRODUCTS") 
plt.ylabel("Price in Kenyan Shillings (UDS / 127)") 
plt.legend() 
# Set the Y-axis limits 
plt.ylim(600, 1600) 
# Display the graph 
plt.xticks(rotation=45) 
plt.tight_layout()
plt.grid() 
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Assuming hjcream is your DataFrame

# Set the X-axis range
x = np.arange(len(hjbutter["BATH AND BODY WORKS PRODUCTS"]))

# Bar width
width = 0.35

# Plotting the grouped bar graph
fig, ax = plt.subplots(figsize=(14, 8))
bar1 = ax.bar(x - width/2, hjbutter["Number of products"], width, label='Number of Products', color='skyblue')
bar2 = ax.bar(x + width/2, hjbutter["Products Sold"], width, label='Products Sold', color='orange')

# Adding title and labels
ax.set_title("Number of butter Products bought Against the Products Sold")
ax.set_xlabel("BATH AND BODY WORKS PRODUCTS")
ax.set_ylabel("Quantity")
ax.set_xticks(x)
ax.set_xticklabels(hjbutter["BATH AND BODY WORKS PRODUCTS"], rotation=45, ha='right')
ax.legend()

# Adjust layout to fit all elements
plt.tight_layout()
plt.grid(axis='y')

# Display the graph
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming hjcream is your DataFrame and it already has the 'Profit per product' column

# Plotting the bar graph
plt.figure(figsize=(14, 8))
plt.bar(hjbutter["BATH AND BODY WORKS PRODUCTS"], hjbutter["Profit per product"], color='green')

# Adding title and labels
plt.title("Profit per butter Product")
plt.xlabel("BATH AND BODY WORKS PRODUCTS")
plt.ylabel("Profit per Product in Kenyan Shillings")

# Adjust layout to fit all elements
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Display the graph
plt.grid(axis='y')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming hj is your DataFrame

# Step 1: Filter out the row that contains the totals
# Replace 'Total' with the actual value in the column which identifies the totals row
hj_filtered = hj[hj["BATH AND BODY WORKS PRODUCTS"] != 'Totals']

# Step 2: Sort the DataFrame by "Products Sold" in descending order
hj_sorted = hj_filtered.sort_values(by="Products Sold", ascending=False)

# Step 3: Select the top ten products
top_ten_products = hj_sorted.head(10)

# Step 4: Plotting the bar graph
plt.figure(figsize=(14, 8))
plt.bar(top_ten_products["BATH AND BODY WORKS PRODUCTS"], top_ten_products["Products Sold"], color='blue')

# Adding title and labels
plt.title("Top 10 Products Sold")
plt.xlabel("BATH AND BODY WORKS PRODUCTS")
plt.ylabel("Products Sold")

# Adjust layout to fit all elements
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Display the graph
plt.grid(axis='y')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming hj is your DataFrame

# Step 1: Filter out the row that contains the totals
# Replace 'Total' with the actual value in the column which identifies the totals row
hj_filtered = hj[hj["BATH AND BODY WORKS PRODUCTS"] != 'Totals']

# Step 2: Sort the DataFrame by "Profit per product" in descending order
hj_sorted = hj_filtered.sort_values(by="Profit per product", ascending=False)

# Step 3: Select the top ten products
top_ten_products = hj_sorted.head(10)

# Step 4: Plotting the bar graph
plt.figure(figsize=(14, 8))
plt.bar(top_ten_products["BATH AND BODY WORKS PRODUCTS"], top_ten_products["Profit per product"], color='green')

# Adding title and labels
plt.title("Top 10 Products with Highest Profit")
plt.xlabel("BATH AND BODY WORKS PRODUCTS")
plt.ylabel("Profit per Product in Kenyan Shillings")

# Adjust layout to fit all elements
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Display the graph
plt.grid(axis='y')
plt.show()

# %%
import pandas as pd

# Assuming hj is your DataFrame

# Step 1: Filter out the row that contains the totals
# Replace 'Total' with the actual value in the column which identifies the totals row
hj_filtered = hj[hj["BATH AND BODY WORKS PRODUCTS"] != 'Total']

# Step 2: Sort the DataFrame by "Products Sold" in ascending order
hj_sorted = hj_filtered.sort_values(by="Products Sold", ascending=True)

# Step 3: Select the top ten products with the least sales
top_ten_least_sold = hj_sorted.head(10)

# Step 4: Extract the names of these products
top_ten_least_sold_products = top_ten_least_sold["BATH AND BODY WORKS PRODUCTS"].tolist()

# Display the names of the top ten least sold products
print("Top 10 Products with the Least Sales:")
for product in top_ten_least_sold_products:
    print(product)
# Out:
# Top 10 Products with the Least Sales:
# Luminous Body Cream
# Japanese Cherry Blossom Body Lotion
# Into The Night Body Cream
# Peach Bellini Body Lotion
# After Dark Body Cream (Men)
# Hello Beautiful Body Cream
# Luminous Glowtion Body Butter
# Graphite Body Cream (Men)
# Bourbon Face and body wash (Men)
# Canyon Body Cream (men)

# %%
import pandas as pd

# Assuming hj is your DataFrame

# Step 1: Filter out the row that contains the totals
# Replace 'Total' with the actual value in the column which identifies the totals row
hj_filtered = hj[hj["BATH AND BODY WORKS PRODUCTS"] != 'Totals']

# Step 2: Sort the DataFrame by "Profit per product" in ascending order
hj_sorted = hj_filtered.sort_values(by="Profit per product", ascending=True)

# Step 3: Select the top ten products with the least profit
top_ten_least_profit = hj_sorted.head(10)

# Step 4: Extract the names of these products
top_ten_least_profit_products = top_ten_least_profit["BATH AND BODY WORKS PRODUCTS"].tolist()

# Display the names of the top ten products with the least profit
print("Top 10 Products with the Least Profit:")
for product in top_ten_least_profit_products:
    print(product)
# Out:
# Top 10 Products with the Least Profit:
# Mahogany Teakwood Deodorant (Men)
# Bourbon Deodorant (Men)
# Ocean Deodorant (Men)
# Mahogany Teakwood Face&Body Wash (Men)
# Ocean Face &Body Wash (Men)
# Gingham Legend, Hair, Face, & Body Wash(Men)
# Bourbon Face and body wash (Men)
# Gingham Legend Body Spray (Men)
# Bourbon Body Spray (Men)
# Mahogany Teakwood Body Spray (Men)

# %%
hjmist
# Out:
# 0                     BATH AND BODY WORKS PRODUCTS Number of products  \
# 0                  A thousand Wishes, Diamond Mist                  2
# 1  Into The Night Diamond Shimmer Mist Body splash                  1
#
# 0 Labelled Price per Product in Dollars($)  \
# 0                                    16.95
# 1                                    16.95
#
# 0 Original Price per Product in Dollars($)  \
# 0                                      8.5
# 1                                     8.47
#
# 0 Original Price for all Products in Dollars($) Rate  \
# 0                                            17  127
# 1                                          8.47  127
#
# 0 Original Price per Product in Kenyan Shillings  \
# 0                                         1079.5
# 1                                        1075.69
#
# 0 Original Price for all Products in Kenyan Shillings  \
# 0                                               2159
# 1                                            1075.69
#
# ...

# %%
hj.to_excel('hjprofit per product.xlsx', index=False)
